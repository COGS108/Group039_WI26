# %% [markdown]
# # COGS 108 - Project Proposal
#
# ## Authors

# %% [markdown]
# - Boyu Tian : Methodology, Background research, Writing - original draft, Analysis, Writing - review & editing
# - Ziming Zhu : Visualization, Project administration, Writing - original draft, Data curation
# - Haoshuo Bi: Methodology, Writing - original draft, Analysis, Data curation
# - Xukuan Wang : Visualization, Writing - original, draft Software, Methodology, Conceptualization

# %% [markdown]
# ## Research Question

# %% [markdown]
# We seek to examine: Are NBA players' heights related to on-court performance, and does this relationship vary by position (guard, forward and center)? We’ll take height (inches) as the main predictor, and we want to measure its effect on achievement in terms of performance metrics (e.g., PER and FGM) (or related statistics; i.e. points, rebounds, assists). We will contrast how the height–achievement relationship applies across roles within position group to examine role specificity of the pattern. We will control for such potential confounds as weight, age/experience, minutes played, and wingspan and see if height still makes a difference. We’ll be using correlation and regression models, and visualizations (like scatterplots with trend lines) to illustrate it’s strength as well as direction of our relationship. The result will be an analytical answer to the question of whether taller players are, in fact, better and whether that is position-dependent.

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Basketball performance depends on a combination of skill, tactics and physical characteristics, and theNBAis an ideal scenario as player measurements (e.g., height) and performance factors are recorded from several seasons. Because height affects what roles you play (rim protector, rebounder, shot contestor), and because it can vary systematically between positions in leagues, researchers and writers frequently discuss whether taller players really do achieve better outcomes—or if the benefits of being tall lie somewhere that’s mediated by position or how one plays, or even other things like arm length or conditioning. In this work, we examine the role of player height on performance/achievement in NBA players by season and position using basic statistical summaries of performance available for all NBA players. <sup>[1](#fn1)</sup>
#
# One challenge is defining “achievement” in a measurable and comparable way. Most descriptions rely on a single-number summary that collapses many box-score contributions into an indication of overall impact. A common one that is referred to many times throughout the game now based on Cubs' broadcasts, is Player Efficiency Rating (PER) which takes good and bad stats and wraps them up into a per-minute stat designed to encapsulate efficiency. PER is one of the most widely used statistics in public basketball analytics because it can easily be compared between players and over seasons, but PER is nonetheless a model-based statistic with well-known limitations (e.g., it depends on a weighting scheme and box-score availability). The PER can be employed in our project as one endogenous variable, because it’s an effective cover to the total statistical contribution that is compared with height over various subgroups of players. <sup>[2](#fn2)</sup>
#
# Previous work has also shown that anthropometric characteristics and body proportions can be associated with outcomes on the proxy of “success” in the NBA. For example, many studies of body proportions and NBA players report correlations between things like wingspan-to-height ratios and metrics such as draft position, while also making clear that loads of other factors (skill, role, team context) contribute to performance and career outcomes. <sup>[3](#fn3)</sup>
#
# There are also similar works linking anthropometrics with strategy and lineup success. Zhang et al. explore how anthropometric factors can be used both to describe elite basketball lineups and performance patterns (including discussion around “small-ball” and lineup construction) underscoring the point that body size may matter differently based on a team’s deployment of players in relation to their role/s played. This supports our approach of considering results by position (i.e. guard/forward/center) instead of forcing one global relationship between height and achievement. <sup>[1](#fn1)</sup>
#
# Finally, such questions are often examined in public analytics projects. Sivori’s study on height and free-throw percentage, for instance, presents a case where size is conditionally related to a skill outcome in some non-obvious way — and it serves as a useful textbook illustration of the kind of workflow you’d use to not-quite prove that sort of thing about NBA players. In contrast to that more specific skill-based outcome, our study examines broader types of performance (e.g., PER and potentially scoring-based metrics such as field goals made), and will also examine if the strength of relationships differs by position or season. <sup>[4](#fn4)</sup>
#
# ---
#
# <a name="fn1"></a>Zhang et al. (and related work summarized in): *Clustering Performances in Elite Basketball Matches According to the Anthropometric Features of the Line-ups Based on Big Data Technology*. [https://pmc.ncbi.nlm.nih.gov/articles/PMC9309682/](https://pmc.ncbi.nlm.nih.gov/articles/PMC9309682/)
#
# <a name="fn2"></a> NBAStuffer. “PER – Player Efficiency Rating (Definition).” [https://www.nbastuffer.com/analytics101/player-efficiency-rating/](https://www.nbastuffer.com/analytics101/player-efficiency-rating/)
#
# <a name="fn3"></a>3. Monson, T. A., Brasil, M. F., & Hlusko, L. J. (2018). Allometric variation in modern humans and the relationship between body proportions and elite athletic success. Journal of Anthropology of Sport and Physical Education, 2(3), 3–8. https://jaspe.ucg.ac.me/?artid=38&sekcija=article
#
# <a name="fn4"></a>Sivori, D. (2021). *NBA Player Height vs. Free Throw Percentage*. [https://dylan-sivori.github.io/2021-02-05-nba-ft-percent/](https://dylan-sivori.github.io/2021-02-05-nba-ft-percent/)

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We predict a strong correlation between the height of NBA players and on-court performances, and we also predict that this relationship does vary by the position of the NBA players.
#
# Since many previous studies and results had shown that the height of basketball players has an influence on their on-court performances, and that this influence is also related to the position of the players. For example, article by Tânia Santos describes that using a sample based on 508 NBA players in season 2018/2019 scraped from the NBA Advanced Stats, the height and rebounded balls percentage relationship was examined by using Pearson’s correlation coefficient and revealed a strong correlation coefficient (r=.554, p= 0.000 < 0.05), which indicates that higher the height of the players the greater is the percentage of offensive rebounds. <sup>[5](#fn5)</sup> The article also describes a relationship between the height of the NBA players and their position, as the article also describes that according to the data, center players are more likely to be the tallest than Shooting guards.<sup>[5](#fn5)</sup> These data suggests that there are correlations between the height of a NBA player and their performance, and their position very likely has an influence on this relationship as the players of certain positions tend to be of different heights.
#
# <a name="fn5"></a>Santos, T. (2019, May 6). The height influence on NBA players. Medium. (https://medium.com/quarkanalytics/the-height-influence-on-nba-players-2eff9c821d5)

# %% [markdown]
# ## Data

# %% [markdown]
# The ideal datasets we would need to best answer our question should be player–season level NBA dataset that combines and contained key variables including the height of players in inches, weight, age, minutes played, years of experience, position of the players, and also the Player Efficiency Rating (PER) and traditional box-score statistics such as field goals made, points, etc. The datasets should also include data of multiple NBA seasons, and containing all of the observations of player performances and other data during this time range to allow reliable correlation and analyses on both overall and by position groups. All the datasets should be in CSV format if possible for better organization.
#
# Some real datasets that can be helpful for the project includes: NBA Players stats since 1950, https://www.kaggle.com/datasets/drgilermo/nba-players-stats/data, which includes the name, heights and weight of NBA players since 1950.
#
# NBA Player Data 2009-2023, https://www.kaggle.com/datasets/sidlamsal/nba-player-data-2009-2023, which includes the name, position, games played, games started, field goal percentage, and field goals attempted of NBA players from 2009 to 2023.
#
# NBA Player Data from 2003 to 2022, https://www.kaggle.com/datasets/dhruvsuryavanshi/nba-player-data-from-2003-to-2022, which includes the position, name, age, average field goals made, average field goals percentage, average 3 pointers made, average 2 pointers made, different average rebounds per game, average personal fouls per game, average points per game, points won by the player to win the MVP award, share of total points a player received that season, minutes played, and many other match data of NBA players from 2003 to 2022.

# %% [markdown]
# ## Ethics
#
# Instructions: Keep the contents of this cell. For each item on the checklist
# -  put an X there if you've considered the item
# -  IF THE ITEM IS RELEVANT place a short paragraph after the checklist item discussing the issue.
#
# Items on this checklist are meant to provoke discussion among good-faith actors who take their ethical responsibilities seriously. Your teams will document these discussions and decisions for posterity using this section.  You don't have to solve these problems, you just have to acknowledge any potential harm no matter how unlikely.
#
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
# > Our project uses publicly available NBA player data collected from official league statistics and public analytics websites. All data were originally collected with appropriate consent and made publicly accessible.
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# > We acknowledge that NBA data reflects a highly selective population of elite athletes and may not generalize to broader populations. Additionally, player roles and minutes played may bias performance statistics. We will account for this by controlling for position and minutes played in our analysis.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
# > The dataset contains no personally identifiable information beyond publicly known player attributes (e.g., height, age). No private or sensitive personal data are used.
#
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# > We recognize that performance metrics may differ systematically by position and physical attributes. Our analysis explicitly separates players by position to avoid misleading aggregate conclusions.
#
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#
# > All data are stored locally within the course GitHub repository and UCSD DataHub environment, which follow standard access control and security practices.
#
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#
# > Since all data are publicly available and contain no private personal information, requests for data removal are not applicable.
#
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# > The data will be retained only for the duration of the course project and will not be used beyond academic purposes.
#
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
# > We acknowledge that quantitative performance metrics may not capture qualitative aspects such as leadership or team dynamics. Our conclusions will be framed accordingly.
#
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
# > We recognize potential biases arising from position-specific roles and unequal playing time. We mitigate this by using regression models with control variables and stratified analysis.
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
# > All visualizations and statistical summaries will accurately reflect the data without exaggeration or selective reporting.
#
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#
# > No private or sensitive data are included in the analysis.
#
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# > Our analysis will be documented and reproducible using version-controlled code and notebooks.
#
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#
# >  Height is a core variable of interest rather than a proxy for protected attributes. We do not use variables intended to approximate sensitive personal characteristics.
#
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#
# > We assess results separately by player position to avoid unfair comparisons across structurally different roles.
#
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#
# > Multiple performance metrics (e.g., PER, points, rebounds) are considered to reduce reliance on any single imperfect measure.
#
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#
# > We use interpretable models such as correlation and linear regression to ensure results can be clearly explained.
#
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# > We will clearly state the limitations of our data and models, including the observational nature of the analysis.
#
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
#     This project is purely exploratory and academic in nature. No model will be deployed in a real-world decision-making context, and therefore deployment-related risks are minimal.

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# * *Communication channel & response time: We will use Discord as our primary communication channel. We aim to respond within 24 hours on weekdays. Important decisions and updates will be summarized in the main Discord channel so everyone stays aligned.*
# * *Meeting schedule: We will meet at least once per week. Meetings will be held virtually unless the team agrees to meet in person. Each meeting will have a short agenda and end with clear action items and owners.*
# * *Task ownership: Every task will have a clear owner + deadline. If someone cannot meet a deadline, they will notify the group at least 24 hours in advance and propose a new plan.*
# * *Work quality & reproducibility: Before pushing, members will ensure their work is clear, documented, and the notebook can run from top-to-bottom.*
# * *Division of labor: We will split work fairly across writing, coding, and analysis. Everyone will contribute to both content (writing) and technical work as appropriate.*
# * *Respect & collaboration: We will communicate respectfully, assume good intent, and give constructive feedback. Disagreements will be discussed calmly with evidence (data/rubric) guiding decisions.*
# * *Conflict resolution: If a conflict cannot be resolved within the group, we will escalate early (TA/instructor) rather than waiting until deadlines.*

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 2/4  |  1 PM | Finalize ProjectProposal.ipynb draft; add citations/footnotes; delete rubric cell; Restart & Run All  | Final review proposal (RQ, hypothesis, data plan, ethics, timeline); assign roles for Data Checkpoint |
# | 2/9  |  7 PM |  Download/get data; store in data/ (or script to fetch); write initial loading code | Confirm unit of analysis; decide cleaning rules (missing values/outliers); split wrangling tasks |
# | 2/11  | 7 PM  | Clean/wrangle v1; document steps; create codebook; draft 01 sections (dataset description + source citation)  | Review wrangling; check reproducibility; plan remaining tasks for 01-DataCheckpoint.ipynb   |
# | 2/14  | 6 PM  | Finish 01-DataCheckpoint.ipynb (data source, ideal vs real dataset, storage/organization, wrangling summary) | Restart & Run All; polish writing; confirm what to submit   |
# | 2/18  | 7 PM  | Submit Data Checkpoint via git commit/push | Post-submit plan: list EDA questions + required plots; assign EDA plot owners |
# | 2/23  | 7 PM | EDA plots v2 + captions; start 02-EDACheckpoint.ipynb write-up | Decide final metrics + baseline method(s); confirm train/test or statistical test plan |
# | 3/4  | 7 PM  | Submit EDA Checkpoint via git commit/push | Lock in final analysis pipeline; assign final notebook sections and responsibilities |
# | 3/8  | 7 PM  | Run main analysis/model (baseline + improved); save key tables/figures in results/ | Debug issues; check assumptions/validity; decide what goes into Results vs Discussion |
# | 3/11  | 7 PM  | Draft 03-FinalProject.ipynb (methods, results, discussion, limitations, ethics) | Peer review writing; ensure narrative matches rubric; plan video outline |
# | 3/15  | 7 PM  | Finalize notebook visuals + text; Restart & Run All; clean outputs; draft video script/slides | Final QA checklist; confirm all team contributions; prepare final push |
# | 3/18  | 7 PM  | Submit Final project + Video; complete Post-course + Team Evaluation surveys | Confirm submission success; backup final files |
